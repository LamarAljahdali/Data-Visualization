# %% [markdown]
# # Student Performance Data Visualization Project
#
# ##**Lamar Aljahdali**

# %% [markdown]
# Data source link- contains data info as well
# http://archive.ics.uci.edu/dataset/320/student+performance

# %% [markdown]
# [Download Data](https://www.kaggle.com/datasets/devansodariya/student-performance-data/download?datasetVersionNumber=1)

# %% [markdown]
# This project examines the academic performance of secondary education students in two Portuguese schools using data encompassing various factors such as student grades, demographics, social background, and school-related features. The information was gathered through school reports and questionnaires, yielding two separate datasets focusing on performance in Mathematics (mat) and the Portuguese language (por). It's crucial to note that the target attribute G3 strongly correlates with G2 and G1. This correlation arises because G3 represents the final year grade (from the 3rd period), whereas G1 and G2 stand for grades in the 1st and 2nd periods respectively.

# %% [markdown]
# **Additional information about the dataset**
#
# ---
#
# 1 school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# 2 sex - student's sex (binary: 'F' - female or 'M' - male)
#
# 3 age - student's age (numeric: from 15 to 22)
#
# 4 address - student's home address type (binary: 'U' - urban or 'R' - rural)
#
# 5 famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# 6 Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# 7 Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)
#
# 8 Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)
#
# 9 Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# 10 Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# 11 reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#
# 12 guardian - student's guardian (nominal: 'mother', 'father' or 'other')
#
# 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16 schoolsup - extra educational support (binary: yes or no)
#
# 17 famsup - family educational support (binary: yes or no)
#
# 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19 activities - extra-curricular activities (binary: yes or no)
#
# 20 nursery - attended nursery school (binary: yes or no)
#
# 21 higher - wants to take higher education (binary: yes or no)
#
# 22 internet - Internet access at home (binary: yes or no)
#
# 23 romantic - with a romantic relationship (binary: yes or no)
#
# 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30 absences - number of school absences (numeric: from 0 to 93)
#
# these grades are related with the course subject, Math or Portuguese:
#
# G1 - first period grade (numeric: from 0 to 20)
#
# G2 - second period grade (numeric: from 0 to 20)
#
# G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# # **Setup**

# %%
# Data Analysis
import numpy as np
import pandas as pd

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Aesthetic configuration for seaborn and matplotlib
plt.rcParams["font.family"] = "monospace"
sns.set_theme(style='darkgrid', palette='rocket')

# %%
df = pd.read_csv("student_data.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ## **EDA**
# This section concerns the relationship between various features in this dataset.

# %% [markdown]
# ##Cleaning

# %%
#Check for missing values

df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# There are no missing values in this dataset

# %% [markdown]
# ## Checking for outliers

# %%
columns_to_plot = ['age']  # Replace these with your desired column names

plt.figure(figsize=(10, 6))

# Use the boxplot function on the selected columns
df[columns_to_plot].boxplot()

# Show the plot
plt.show()

# %%
columns_to_plot = ['Medu','Fedu','traveltime','studytime','failures','famrel','freetime','goout','Dalc','Walc','health']  # Replace these with your desired column names

plt.figure(figsize=(10, 6))

# Use the boxplot function on the selected columns
df[columns_to_plot].boxplot()

# Show the plot
plt.show()

# %%
columns_to_plot = ['absences']  # Replace these with your desired column names

plt.figure(figsize=(10, 6))

# Use the boxplot function on the selected columns
df[columns_to_plot].boxplot()

# Show the plot
plt.show()

# %%
columns_to_plot = ['G1','G2','G3']  # Replace these with your desired column names

plt.figure(figsize=(10, 6))

# Use the boxplot function on the selected columns
df[columns_to_plot].boxplot()

# Show the plot
plt.show()

# %% [markdown]
# We can see that there are multiple outliers that need to be removed

# %% [markdown]
# ## Removing Outliers

# %%
#sort the dataset
sorted(df)
# Out:
# ['Dalc',
#  'Fedu',
#  'Fjob',
#  'G1',
#  'G2',
#  'G3',
#  'Medu',
#  'Mjob',
#  'Pstatus',
#  'Walc',
#  'absences',
#  'activities',
#  'address',
#  'age',
#  'failures',
#  'famrel',
#  'famsize',
#  'famsup',
#  'freetime',
#  'goout',
#  'guardian',
#  'health',
#  'higher',
#  'internet',
#  'nursery',
#  'paid',
#  'reason',
#  'romantic',
#  'school',
#  'schoolsup',
#  'sex',
#  'studytime',
#  'traveltime']

# %% [markdown]
# ## Applying IQR approach to remove outliers

# %%
Q1= df.loc[:, df.columns!='failures'].quantile(0.25)
Q3= df.loc[:, df.columns!='failures'].quantile(0.75)
IQR= Q3-Q1
print(IQR)
# Out:
# age           2.0
# Medu          2.0
# Fedu          1.0
# traveltime    1.0
# studytime     1.0
# famrel        1.0
# freetime      1.0
# goout         2.0
# Dalc          1.0
# Walc          2.0
# health        2.0
# absences      8.0
# G1            5.0
# G2            4.0
# G3            6.0
# dtype: float64
# <ipython-input-12-7bce5e83919c>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1= df.loc[:, df.columns!='failures'].quantile(0.25)
# <ipython-input-12-7bce5e83919c>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3= df.loc[:, df.columns!='failures'].quantile(0.75)

# %%
# Determine lower bound (lb) and upper bounds (ub)
lb=Q1-(1.5*IQR)
ub=Q3+(1.5*IQR)

# %%
# store modified dataset (mstudent)
student=df[~((df<lb)|(df>ub))]
# Out:
# <ipython-input-14-4d886e02420d>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   student=df[~((df<lb)|(df>ub))]

# %% [markdown]
# ###We will observe the absences since it has more outliers

# %%
student['absences'].describe()
# Out:
# count    380.000000
# mean       4.602632
# std        4.968236
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%        7.000000
# max       20.000000
# Name: absences, dtype: float64

# %%
# remove outliers in absences column
fstudent=student[student['absences']<11]

# %%
sns.boxplot(x='absences', data=fstudent)
# Out:
# <Axes: xlabel='absences'>

# %%
fstudent['absences'].describe()
# Out:
# count    329.000000
# mean       3.045593
# std        3.057536
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        5.000000
# max       10.000000
# Name: absences, dtype: float64

# %% [markdown]
# All outliers removed successfully

# %% [markdown]
# ##Perform Feature Engineering/Relationship Analysis

# %%
# checking relationship based on pearson correlation coefficient

corr=fstudent.corr() #displays a correlation matrix
corr
# Out:
# <ipython-input-19-0ac9e60550c4>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=fstudent.corr() #displays a correlation matrix
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.209802 -0.190919    0.159145   0.069299  0.172581
# Medu       -0.209802  1.000000  0.644732   -0.134044   0.114453 -0.258639
# Fedu       -0.190919  0.644732  1.000000   -0.115012   0.092022 -0.266569
# traveltime  0.159145 -0.134044 -0.115012    1.000000  -0.146317  0.094377
# studytime   0.069299  0.114453  0.092022   -0.146317   1.000000 -0.148710
# failures    0.172581 -0.258639 -0.266569    0.094377  -0.148710  1.000000
# famrel      0.030608  0.082255  0.059209   -0.013338   0.063450 -0.061899
# freetime    0.033476  0.027885  0.022246   -0.042975  -0.116525  0.103436
# ...

# %% [markdown]
# ##Visualizing Data Correlation

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,annot=True, cmap="Spectral") #visualize correlation matrix
# Out:
# <Axes: >

# %% [markdown]
# From the figure above we can view some high correlations between the three periods and the final grade since they are related to each other. We can also see a high correlation between Time productivity and Study time which will view more into.

# %% [markdown]
# ##Comparing School proportion

# %%
plt.figure(figsize=(10, 8))

# Define colors for the pie chart
colors = ['lightblue', 'lightgreen']

fstudent['school'].value_counts().plot(kind='pie', autopct='%.0f%%', colors=colors)
plt.title('School Proportion')
plt.legend()
plt.show()

# %% [markdown]
# We have a dominance of GP School with 88%

# %% [markdown]
# ##Sex

# %%
# Define colors for the pie chart
colors = ['lightblue', 'lightgreen']

plt.figure(figsize=(10,8))
df.sex.value_counts().plot(kind='pie', autopct='%.0f%%', colors = colors)
plt.title('Sex proportion in %')
plt.legend()

# %% [markdown]
#   This shows that we have a larger number of female student rather than males

# %% [markdown]
# ##Age

# %%
# Set the entire count plot in light blue color
plt.figure(figsize=(10, 8))
sns.countplot(data=fstudent, x='age', color='lightblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This shows that the majority of students are between the age of 15 and 18

# %% [markdown]
# ##Visualizing Relationship between G1,G2 & G3

# %%
sns.pairplot(
    fstudent,
    x_vars=["G1", "G2"],
    y_vars=["G1", "G2", "G3"],
)

# %% [markdown]
# This shows that student who score good grade in G1 and G2 will eventually score a good final grade

# %% [markdown]
# ##Student Performance in G1,G2 & G3 accross Schools

# %%
sns.pairplot(
    fstudent,
    x_vars=["G1", "G2"],
    y_vars=["G1", "G2", "G3"],
    hue="school"
)

# %% [markdown]
# Students who perform well on their first and second period grades in Gabriel Pereira school generally perform better on their final grade compared to students of Mousinho da Silveira school.

# %% [markdown]
# ## Health vs. Grade

# %%
sns.barplot(x="health",y="G3", hue="school", data=fstudent, ci=False)
# Out:
# <ipython-input-26-e0bbe5546f24>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="health",y="G3", hue="school", data=fstudent, ci=False)
# <Axes: xlabel='health', ylabel='G3'>

# %% [markdown]
# This shows that people with low health are getting higher grades

# %% [markdown]
# ## Counting the students in Urban and Rural areas to see if that will make the previous figure make sense

# %%
plt.figure(figsize=(10, 8))

# Creating a count plot for 'address' with 'school' as hue
sns.countplot(data=fstudent, x='address', hue='school')

# Set labels and title
plt.xlabel('Address Type')
plt.ylabel('Count')
plt.title('Count of Individuals by Address Type and School')

plt.legend(title='School')

plt.show()

# %% [markdown]
# This shows that most students are in urban areas, which doesn't clarify the high number of low health students

# %% [markdown]
# ##Alcohol vs. Address

# %%
plt.figure(figsize=(10, 8))

# Creating a bar plot for 'Dalc' with 'address' and 'school' as hue
sns.barplot(data=fstudent, x='Dalc', y='address', hue='school', ci=None)

# Set labels and title
plt.xlabel('Workday Alcohol Consumption (Dalc)')
plt.ylabel('School')
plt.title('Workday Alcohol Consumption by Address and School')

plt.legend(title='Address')

plt.show()

plt.figure(figsize=(10, 8))

# Creating a bar plot for 'Walc' with 'address' and 'school' as hue
sns.barplot(data=fstudent, x='Walc', y='address', hue='school', ci=None)

# Set labels and title
plt.xlabel('Weekend Alcohol Consumption (Walc)')
plt.ylabel('School')
plt.title('Weekend Alcohol Consumption by Address and School')

plt.legend(title='Address')

plt.show()
# Out:
# <ipython-input-53-d39780588136>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=fstudent, x='Dalc', y='address', hue='school', ci=None)
# <ipython-input-53-d39780588136>:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=fstudent, x='Walc', y='address', hue='school', ci=None)

# %% [markdown]
# This can justify the high number of students with low health

# %% [markdown]
# ##Health vs. Family size

# %%
plt.figure(figsize=(10, 6))

# Creating a grouped bar plot for 'health' vs 'famsize'
sns.countplot(data=fstudent, x='health', hue='famsize', palette='pastel')
plt.title('Health vs Family Size')

# Set labels and title
plt.xlabel('Health')
plt.ylabel('Count')
plt.legend(title='Family Size')

plt.show()

# %% [markdown]
# This shows that students with 3 or more siblings are in better health overall than students with less siblings

# %% [markdown]
# ##Famsize vs. Address

# %%
plt.figure(figsize=(8, 6))

# Creating a grouped count plot for 'famsize' vs 'address'
sns.countplot(data=fstudent, x='famsize', hue='address')

# Set labels and title
plt.xlabel('Family Size')
plt.ylabel('Count')
plt.title('Comparison of Family Size with Address Type')

plt.legend(title='Address Type')

plt.show()

# %% [markdown]
# This shows that most urban area families have more than 3 person per family

# %% [markdown]
# ## Family Size vs. Grade

# %%
sns.barplot(x="famsize",y="G3", hue="school", data=fstudent, ci=False)
# Out:
# <ipython-input-31-50fd6f0324f4>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="famsize",y="G3", hue="school", data=fstudent, ci=False)
# <Axes: xlabel='famsize', ylabel='G3'>

# %% [markdown]
# This shows that students with less siblings have better grade, that could be because of the less distraction

# %% [markdown]
# ## Absences vs. Grade

# %%
sns.barplot(x="absences",y="G3", hue="school", data=fstudent, ci=False)
# Out:
# <ipython-input-32-8cc9ee890e16>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="absences",y="G3", hue="school", data=fstudent, ci=False)
# <Axes: xlabel='absences', ylabel='G3'>

# %% [markdown]
# Absences and grade doesn't show a clear relation, this might because students can keep up with the material even when not present

# %%
plt.figure(figsize=(15, 8))

corr = fstudent[['absences', 'G1', 'G2', 'G3']].corr()

# Creating the heatmap with the 'Spectral' color theme
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap='Spectral')

# Set title
plt.title('Correlation Heatmap')

plt.show()

# %% [markdown]
# This shows that there is no relation clearly

# %% [markdown]
# ## Age vs. Grade

# %%
sns.barplot(x="age",y="G3", hue="school", data=fstudent, ci=False)
# Out:
# <ipython-input-34-c53f24b18a5f>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="age",y="G3", hue="school", data=fstudent, ci=False)
# <Axes: xlabel='age', ylabel='G3'>

# %% [markdown]
# This shows the distribution of grades among student ages, where 20 gets the higher grade that might be because there are very few 20yrs old student and they might have got high grades which can play with the bars. But overall most student are between 15-18 and they show higher grade than 19 and 21.

# %%
plt.figure(figsize=(10, 6))

# Creating a grouped count plot for 'age' by 'school'
sns.countplot(data=fstudent, x='age', hue='school')

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Count of Students Grouped by Ages in Each School')

plt.legend(title='School')

plt.show()

# %% [markdown]
# This shows that MS school doesn't have students ages 15 and 16, that gives reasons for the missing bars above. And this also shows that the number of student age 20 are very low. Which can result in a high grade bar if the few students are getting high grades.

# %% [markdown]
# ## Study time vs. final grade

# %%
sns.barplot(x="studytime",y="G3", hue="school", data=fstudent, ci=False)
# Out:
# <ipython-input-36-f514869d8338>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="studytime",y="G3", hue="school", data=fstudent, ci=False)
# <Axes: xlabel='studytime', ylabel='G3'>

# %% [markdown]
# This shows that more study time resovles in higher grades

# %% [markdown]
# ##Travel time vs. Final grade

# %%
sns.barplot(x='traveltime', y='G3', data=fstudent, ci=False)
# Out:
# <ipython-input-37-ab31f69aa11c>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='traveltime', y='G3', data=fstudent, ci=False)
# <Axes: xlabel='traveltime', ylabel='G3'>

# %% [markdown]
# This shows that students with more travel time get lower grades

# %% [markdown]
# ## Education Level vs. Job

# %% [markdown]
# Mothers' Job and Education

# %%
mjob_edu = fstudent.groupby("Mjob").aggregate({"Medu": "mean"})
mjob_edu.reset_index(inplace=True)
mjob_edu.sort_values(by='Medu', ascending=False, inplace=True)

# %%
sns.barplot(x='Mjob', y='Medu', data=mjob_edu).set(xlabel='Job', ylabel='Education Lvl.', title='Job vs. Edu. Lvl. (Mother)')
# Out:
# [Text(0.5, 0, 'Job'),
#  Text(0, 0.5, 'Education Lvl.'),
#  Text(0.5, 1.0, 'Job vs. Edu. Lvl. (Mother)')]

# %% [markdown]
# This shows that higher education level mothers are mostly teachers

# %% [markdown]
# Fathers' Job and Education

# %%
fjob_edu = fstudent.groupby("Fjob").aggregate({"Fedu": "mean"})
fjob_edu.reset_index(inplace=True)
fjob_edu.sort_values(by='Fedu', ascending=False, inplace=True)

# %%
sns.barplot(x='Fjob', y='Fedu', data=fjob_edu).set(xlabel='Job', ylabel='Education Lvl.', title='Job vs. Edu. Lvl. (Father)')
# Out:
# [Text(0.5, 0, 'Job'),
#  Text(0, 0.5, 'Education Lvl.'),
#  Text(0.5, 1.0, 'Job vs. Edu. Lvl. (Father)')]

# %% [markdown]
# This also shows that higher education level fathers are mostly teachers as well

# %% [markdown]
# ## Job vs. Grade

# %% [markdown]
# Mothers' Job

# %%
mjob_gr = fstudent.groupby("Mjob").aggregate({"G3": "mean"}).reset_index()
mjob_gr
# Out:
#        Mjob         G3
# 0   at_home   9.078431
# 1    health  12.241379
# 2     other   9.865546
# 3  services  11.088608
# 4   teacher  11.294118

# %%
sns.barplot(data=fstudent, x='Mjob', y='G3', palette='rocket').set(xlabel='Job', ylabel='Final Grade', title='Job vs. Grade (Mother)')
# Out:
# [Text(0.5, 0, 'Job'),
#  Text(0, 0.5, 'Final Grade'),
#  Text(0.5, 1.0, 'Job vs. Grade (Mother)')]

# %% [markdown]
# This shows that mothers in health jobs have children with higher grades while mother at home have children with lower grades. This can be because of the educational influence on children in homes.

# %% [markdown]
# Fathers' Job

# %%
sns.barplot(data=fstudent, x='Fjob', y='G3', palette='rocket').set(xlabel='Job', ylabel='Final Grade', title='Job vs. Grade (Father)')
# Out:
# [Text(0.5, 0, 'Job'),
#  Text(0, 0.5, 'Final Grade'),
#  Text(0.5, 1.0, 'Job vs. Grade (Father)')]

# %% [markdown]
# This also shows that fathers in health jobs and teachers have children with higher grades while fathers at home have children with lower grades. This can be because of the educational influence on children in homes.

# %% [markdown]
# ## Activites vs. Grade

# %%
sns.barplot(x="activities",y="G3", hue="school", data=fstudent, ci=False)
# Out:
# <ipython-input-45-39776e134a50>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="activities",y="G3", hue="school", data=fstudent, ci=False)
# <Axes: xlabel='activities', ylabel='G3'>

# %% [markdown]
# This shows that students with activities have higher grades, but in MS school its different maybe because of the low number of student.

# %% [markdown]
# ##Going out vs. Grades

# %%
sns.barplot(x="goout",y="G3", hue="school", data=fstudent, ci=False)
# Out:
# <ipython-input-46-e63d68911e69>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="goout",y="G3", hue="school", data=fstudent, ci=False)
# <Axes: xlabel='goout', ylabel='G3'>

# %% [markdown]
# This shows that having an average of 2-3 hours of going out weekly can result in better grades. But exceeding them result in lower grades correspondigly not going out at all also results in lower grade which can be because of stress and anixiety. But it also shows that MS shcool student go out much more, that can be because they are older students.

# %% [markdown]
# #Conlusion

# %% [markdown]
# ### My data had some eye widening insights. It showed what students must and must not do to get higher grades. Additionally, it showed that there might be other reasons for low and high grades other that the student's effort. Such as parents education, health, and area of living. It also made me dive into some details to get more clear results. This project made me learn alot about data visualization, and made me understand it more.
#
# Comparative Discussion:
#
# Some codes showed similar results such as
# "Does travel time affect student grades?
# Answer : yes ,the less travel time, the higher the demand for exam scores" which is the same result I concluded from the Travel vs. Grade figure. "Does the education of the father and mother affect the student's grades?
# Answer : yes , the more parents learn, the higher the student's grades" Also concluded the same result from the Job vs. Grade figure, but I exceeded my results to look more into parent's job according to educational level which wasn't mentioned in the code I viewed. The code also concluded that "The higher the student's score in the first, second period grade and final grade , the higher the student's average score. The higher the student's grades in the first and second period grade, the higher his grades in the final exam." Which is what I concluded from the first figure on relationships between G1, G2, G3. There are also more results to discuss, you can find the reference of the code below.
#
# mohamedmohsen3330. (2023, June 24). data analysis students performance. Retrieved December 12, 2023, from Kaggle.com website: https://www.kaggle.com/code/mohamedmohsen3330/data-analysis-students-performance#3_Data-Exploring
#
# ‌
# Another reference that showed similar results but was very limited is linked below.
#
# ireneagyebi. (2022, August 19). EDA on Student Performance. Retrieved December 12, 2023, from Kaggle.com website: https://www.kaggle.com/code/ireneagyebi/eda-on-student-performance/notebook
#
# ‌
